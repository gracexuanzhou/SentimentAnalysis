# %%
# DataFrame
import pandas as pd

# Matplot
import matplotlib.pyplot as plt
# %matplotlib inline

# Scikit-learn
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from sklearn.manifold import TSNE
from sklearn.feature_extraction.text import TfidfVectorizer

# Keras
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import Activation, Dense, Dropout, Embedding, Flatten, Conv1D, MaxPooling1D, LSTM
from keras import utils
from keras.callbacks import ReduceLROnPlateau, EarlyStopping

# nltk
import nltk
from nltk.corpus import stopwords
from  nltk.stem import SnowballStemmer

# Word2vec
import gensim

# Utility
import re
import numpy as np
import os
from collections import Counter
import logging
import time
import pickle
import itertools

# Set log
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %%
from google.colab import drive
import pandas as pd
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
data_raw = pd.read_csv("/content/gdrive/My Drive/Course/Colab Notebooks/training_1600000.csv",encoding = "ISO-8859-1", header=None)

# %%
# As the data has no column titles, we will add our own
data_raw.columns = ["sentiment", "time", "date", "query", "username", "text"]

# Show the first 5 rows of the dataframe.
# You can specify the number of rows to be shown as follows: df_raw.head(10)
data_raw.head()
# Out:
#    sentiment  ...                                               text
# 0          0  ...  @switchfoot http://twitpic.com/2y1zl - Awww, t...
# 1          0  ...  is upset that he can't update his Facebook by ...
# 2          0  ...  @Kenichan I dived many times for the ball. Man...
# 3          0  ...    my whole body feels itchy and like its on fire
# 4          0  ...  @nationwideclass no, it's not behaving at all....
#
# [5 rows x 6 columns]

# %%
data_raw = data_raw.drop(["time", "date", "query", "username"], axis=1)
data_raw['sentiment'] = data_raw['sentiment'].replace(4,1)
data_raw.head()
# Out:
#    sentiment                                               text
# 0          0  @switchfoot http://twitpic.com/2y1zl - Awww, t...
# 1          0  is upset that he can't update his Facebook by ...
# 2          0  @Kenichan I dived many times for the ball. Man...
# 3          0    my whole body feels itchy and like its on fire
# 4          0  @nationwideclass no, it's not behaving at all....

# %%
# split a sample dataset, using smaller csv to train first
drop_item=data_raw.sample(frac=0.375,random_state=200) #random state is a seed value
dataset=data_raw.drop(drop_item.index)

# %%
dataset['sentiment'].value_counts()
# Out:
# 1    500207
# 0    499793
# Name: sentiment, dtype: int64

# %% [markdown]
# ## Preprocess the text

# %%
# Reading contractions.csv and storing it as a dict.
# shouldn't -> should not
contractions = pd.read_csv('/content/gdrive/My Drive/Course/Colab Notebooks/contractions.csv', index_col='Contraction')
contractions.index = contractions.index.str.lower()
contractions.Meaning = contractions.Meaning.str.lower()
contractions_dict = contractions.to_dict()['Meaning']

# Defining regex patterns.
urlPattern        = r"((http://)[^ ]*|(https://)[^ ]*|(www\.)[^ ]*)"
userPattern       = '@[^\s]+'
hashtagPattern    = '#[^\s]+'
alphaPattern      = "[^a-z0-9<>]"
sequencePattern   = r"(.)\1\1+"
seqReplacePattern = r"\1\1"

# Defining regex for emojis
smileemoji        = r"[8:=;]['`\-]?[)d]+"
sademoji          = r"[8:=;]['`\-]?\(+"
neutralemoji      = r"[8:=;]['`\-]?[\/|l*]"
lolemoji          = r"[8:=;]['`\-]?p+"

def preprocess_apply(tweet):

    tweet = tweet.lower()

    # Replace all URls with '<url>'
    tweet = re.sub(urlPattern,'<url>',tweet)
    # Replace @USERNAME to '<user>'.
    tweet = re.sub(userPattern,'<user>', tweet)
    # Replace #Hashtags to '<hashtags>'.
    #tweet = re.sub(hashtagPattern,'<hashtag>', tweet)
    
    # Replace 3 or more consecutive letters by 2 letter.
    tweet = re.sub(sequencePattern, seqReplacePattern, tweet)

    # Replace all emojis.
    tweet = re.sub(r'<3', '<heart>', tweet)
    tweet = re.sub(smileemoji, '<smile>', tweet)
    tweet = re.sub(sademoji, '<sadface>', tweet)
    tweet = re.sub(neutralemoji, '<neutralface>', tweet)
    tweet = re.sub(lolemoji, '<lolface>', tweet)

    for contraction, replacement in contractions_dict.items():
        tweet = tweet.replace(contraction, replacement)

    # Remove non-alphanumeric and symbols
    tweet = re.sub(alphaPattern, ' ', tweet)

    # Adding space on either side of '/' to seperate words (After replacing URLS).
    tweet = re.sub(r'/', ' / ', tweet)
    return tweet

# %%
# %%time
dataset['processed_text'] = dataset.text.apply(preprocess_apply)
# Out:
# CPU times: user 50.2 s, sys: 81 ms, total: 50.3 s
# Wall time: 50.3 s

# %% [markdown]
# ### Split the dataset

# %%
from sklearn.model_selection import train_test_split

X_data, y_data = np.array(dataset['processed_text']), np.array(dataset['sentiment'])

X_train, X_test, y_train, y_test = train_test_split(X_data, y_data,
                                                    test_size = 0.05, random_state = 0)
print('Data Split done.')
# Out:
# Data Split done.

# %%
from gensim.models import Word2Vec

Embedding_dimensions = 100

# Creating Word2Vec training dataset.
Word2vec_train_data = list(map(lambda x: x.split(), X_train))

# %%
# %%time

# Defining the model and training it.
word2vec_model = Word2Vec(Word2vec_train_data,
                 size=Embedding_dimensions,
                 workers=8,
                 min_count=5)

print("Vocabulary Length:", len(word2vec_model.wv.vocab))
# Out:
# 2020-12-02 22:02:49,265 : INFO : collecting all words and their counts
# 2020-12-02 22:02:49,268 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2020-12-02 22:02:49,303 : INFO : PROGRESS: at sentence #10000, processed 137274 words, keeping 13515 word types
# 2020-12-02 22:02:49,333 : INFO : PROGRESS: at sentence #20000, processed 273521 words, keeping 20452 word types
# 2020-12-02 22:02:49,363 : INFO : PROGRESS: at sentence #30000, processed 410602 words, keeping 25957 word types
# 2020-12-02 22:02:49,393 : INFO : PROGRESS: at sentence #40000, processed 547145 words, keeping 30714 word types
# 2020-12-02 22:02:49,425 : INFO : PROGRESS: at sentence #50000, processed 682502 words, keeping 34954 word types
# 2020-12-02 22:02:49,453 : INFO : PROGRESS: at sentence #60000, processed 817782 words, keeping 38909 word types
# 2020-12-02 22:02:49,486 : INFO : PROGRESS: at sentence #70000, processed 953109 words, keeping 42581 word types
# 2020-12-02 22:02:49,516 : INFO : PROGRESS: at sentence #80000, processed 1088886 words, keeping 46059 word types
# 2020-12-02 22:02:49,544 : INFO : PROGRESS: at sentence #90000, processed 1224173 words, keeping 49478 word types
# 2020-12-02 22:02:49,575 : INFO : PROGRESS: at sentence #100000, processed 1360212 words, keeping 52630 word types
# 2020-12-02 22:02:49,604 : INFO : PROGRESS: at sentence #110000, processed 1496001 words, keeping 55683 word types
# 2020-12-02 22:02:49,633 : INFO : PROGRESS: at sentence #120000, processed 1631792 words, keeping 58558 word types
: INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-12-02 22:03:59,625 : INFO : EPOCH - 4 : training on 12928293 raw words (9517750 effective words) took 15.6s, 608420 effective words/s
# 2020-12-02 22:04:00,655 : INFO : EPOCH 5 - PROGRESS: at 5.94% examples, 555856 words/s, in_qsize 16, out_qsize 0
# 2020-12-02 22:04:01,668 : INFO : EPOCH 5 - PROGRESS: at 12.38% examples, 578792 words/s, in_qsize 13, out_qsize 2
# 2020-12-02 22:04:02,689 : INFO : EPOCH 5 - PROGRESS: at 18.53% examples, 577879 words/s, in_qsize 15, out_qsize 0
# 2020-12-02 22:04:03,690 : INFO : EPOCH 5 - PROGRESS: at 24.80% examples, 582164 words/s, in_qsize 15, out_qsize 0
# 2020-12-02 22:04:04,707 : INFO : EPOCH 5 - PROGRESS: at 30.89% examples, 580048 words/s, in_qsize 14, out_qsize 1
# 2020-12-02 22:04:05,716 : INFO : EPOCH 5 - PROGRESS: at 36.99% examples, 579494 words/s, in_qsize 15, out_qsize 0
# 2020-12-02 22:04:06,722 : INFO : EPOCH 5 - PROGRESS: at 42.89% examples, 576050 words/s, in_qsize 15, out_qsize 0
# 2020-12-02 22:04:07,751 : INFO : EPOCH 5 - PROGRESS: at 49.15% examples, 576480 words/s, in_qsize 15, out_qsize 0
# 2020-12-02 22:04:08,780 : INFO : EPOCH 5 - PROGRESS: at 55.35% examples, 575975 words/s, in_qsize 11, out_qsize 4
# 2020-12-02 22:04:09,816 : INFO : EPOCH 5 - PROGRESS: at 61.60% examples, 575928 words/s, in_qsize 15, out_qsize 0
# 2020-12-02 22:04:10,838 : INFO : EPOCH 5 - PROGRESS: at 68.20% examples, 579177 words/s, in_qsize 15, out_qsize 0
# 2020-12-02 22:04:11,852 : INFO : EPOCH 5 - PROGRESS: at 74.61% examples, 581079 words/s, in_qsize 15, out_qsize 0
# 2020-12-02 22:04:12,866 : INFO : EPOCH 5 - PROGRESS: at 81.42% examples, 585475 words/s, in_qsize 16, out_qsize 0
# 2020-12-02 22:04:13,878 : INFO : EPOCH 5 - PROGRESS: at 87.61% examples, 585224 words/s, in_qsize 16, out_qsize 0
# 2020-12-02 22:04:14,895 : INFO : EPOCH 5 - PROGRESS: at 93.93% examples, 585767 words/s, in_qsize 15, out_qsize 0
# 2020-12-02 22:04:15,838 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-12-02 22:04:15,841 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-12-02 22:04:15,853 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-12-02 22:04:15,867 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-12-02 22:04:15,871 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-12-02 22:04:15,876 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-12-02 22:04:15,885 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-12-02 22:04:15,887 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-12-02 22:04:15,888 : INFO : EPOCH - 5 : training on 12928293 raw words (9518516 effective words) took 16.3s, 585679 effective words/s
# 2020-12-02 22:04:15,890 : INFO : training on a 64641465 raw words (47585195 effective words) took 76.4s, 622624 effective words/s
# Vocabulary Length: 39654
# CPU times: user 2min 37s, sys: 990 ms, total: 2min 38s
# Wall time: 1min 26s

# %% [markdown]
# ## Tokenize and Padding

# %%
# Defining the model input length.
input_length = 60

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
tokenizer = Tokenizer(filters="", lower=False, oov_token="<oov>")
tokenizer.fit_on_texts(X_data)

vocab_length = len(tokenizer.word_index) + 1
print("Tokenizer vocab length:", vocab_length)
# Out:
# Tokenizer vocab length: 205994

# %%
X_train = pad_sequences(tokenizer.texts_to_sequences(X_train), maxlen=input_length)
X_test  = pad_sequences(tokenizer.texts_to_sequences(X_test) , maxlen=input_length)

print("X_train.shape:", X_train.shape)
print("X_test.shape :", X_test.shape)
# Out:
# X_train.shape: (950000, 60)
# X_test.shape : (50000, 60)

# %% [markdown]
# ## Create Embedding matrix

# %%
embedding_matrix = np.zeros((vocab_length, Embedding_dimensions))

for word, token in tokenizer.word_index.items():
    if word2vec_model.wv.__contains__(word):
        embedding_matrix[token] = word2vec_model.wv.__getitem__(word)

print("Embedding Matrix Shape:", embedding_matrix.shape)
# Out:
# Embedding Matrix Shape: (205994, 100)

# %% [markdown]
# ## Create Model

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Bidirectional, GlobalMaxPool1D, Dense, LSTM, Conv1D, Embedding

# %%
def getModel():
    embedding_layer = Embedding(input_dim = vocab_length, 
                                output_dim = Embedding_dimensions,
                                weights=[embedding_matrix], 
                                input_length=input_length,
                                trainable=False)

    model = Sequential([
        embedding_layer,
        Bidirectional(LSTM(100, dropout=0.3, return_sequences=True)),
        Bidirectional(LSTM(100, dropout=0.3, return_sequences=True)),
        Conv1D(100, 5, activation='relu'),
        GlobalMaxPool1D(),
        Dense(16, activation='relu'),
        Dense(1, activation='sigmoid'),
    ],
    name="Sentiment_Model")
    return model

# %%
training_model = getModel()
training_model.summary()
# Out:
# Model: "Sentiment_Model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 60, 100)           20599400
# _________________________________________________________________
# bidirectional (Bidirectional (None, 60, 200)           160800
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 60, 200)           240800
# _________________________________________________________________
# conv1d (Conv1D)              (None, 56, 100)           100100
# _________________________________________________________________
# global_max_pooling1d (Global (None, 100)               0
# _________________________________________________________________
# dense (Dense)                (None, 16)                1616
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 21,102,733
# Trainable params: 503,333
# Non-trainable params: 20,599,400
# _________________________________________________________________

# %% [markdown]
# ### Callbacks and Earlystop

# %%
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping

callbacks = [ReduceLROnPlateau(monitor='val_loss', patience=5, cooldown=0),
             EarlyStopping(monitor='val_accuracy', min_delta=1e-4, patience=5)]

# %% [markdown]
# ### Compile

# %%
training_model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %% [markdown]
# ## Train

# %%
history = training_model.fit(
    X_train, y_train,
    batch_size=1024,
    epochs=15,
    validation_split=0.1,
    callbacks=callbacks,
    verbose=1,
)
# Out:
# Epoch 1/15
# 835/835 [==============================] - 106s 127ms/step - loss: 0.4479 - accuracy: 0.7880 - val_loss: 0.4029 - val_accuracy: 0.8158
# Epoch 2/15
# 835/835 [==============================] - 108s 129ms/step - loss: 0.4098 - accuracy: 0.8111 - val_loss: 0.3906 - val_accuracy: 0.8217
# Epoch 3/15
# 835/835 [==============================] - 107s 129ms/step - loss: 0.3967 - accuracy: 0.8185 - val_loss: 0.3815 - val_accuracy: 0.8278
# Epoch 4/15
# 835/835 [==============================] - 108s 129ms/step - loss: 0.3885 - accuracy: 0.8227 - val_loss: 0.3761 - val_accuracy: 0.8303
# Epoch 5/15
# 835/835 [==============================] - 107s 129ms/step - loss: 0.3827 - accuracy: 0.8265 - val_loss: 0.3715 - val_accuracy: 0.8334
# Epoch 6/15
# 835/835 [==============================] - 107s 129ms/step - loss: 0.3772 - accuracy: 0.8293 - val_loss: 0.3719 - val_accuracy: 0.8340
# Epoch 7/15
# 835/835 [==============================] - 107s 129ms/step - loss: 0.3727 - accuracy: 0.8317 - val_loss: 0.3683 - val_accuracy: 0.8353
# Epoch 8/15
# 835/835 [==============================] - 107s 128ms/step - loss: 0.3694 - accuracy: 0.8335 - val_loss: 0.3651 - val_accuracy: 0.8363
# Epoch 9/15
# 835/835 [==============================] - 107s 128ms/step - loss: 0.3662 - accuracy: 0.8353 - val_loss: 0.3671 - val_accuracy: 0.8368
# Epoch 10/15
# 835/835 [==============================] - 107s 128ms/step - loss: 0.3632 - accuracy: 0.8369 - val_loss: 0.3632 - val_accuracy: 0.8392
# Epoch 11/15
# 835/835 [==============================] - 107s 128ms/step - loss: 0.3609 - accuracy: 0.8381 - val_loss: 0.3651 - val_accuracy: 0.8384
# Epoch 12/15
# 835/835 [==============================] - 106s 127ms/step - loss: 0.3585 - accuracy: 0.8392 - val_loss: 0.3609 - val_accuracy: 0.8399
# Epoch 13/15
# 835/835 [==============================] - 106s 127ms/step - loss: 0.3561 - accuracy: 0.8405 - val_loss: 0.3625 - val_accuracy: 0.8396
# Epoch 14/15
# 835/835 [==============================] - 106s 127ms/step - loss: 0.3546 - accuracy: 0.8411 - val_loss: 0.3633 - val_accuracy: 0.8389
# Epoch 15/15
# 835/835 [==============================] - 106s 127ms/step - loss: 0.3525 - accuracy: 0.8424 - val_loss: 0.3617 - val_accuracy: 0.8395

# %% [markdown]
# ## Evaluate the model

# %%
acc,  val_acc  = history.history['accuracy'], history.history['val_accuracy']
loss, val_loss = history.history['loss'], history.history['val_loss']
epochs = range(len(acc))

plt.plot(epochs, acc, 'b', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()
plt.savefig("/content/gdrive/My Drive/Course/Colab Notebooks/training_process_acc1.png", dpi =300)

plt.figure()

plt.plot(epochs, loss, 'b', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()



plt.savefig("/content/gdrive/My Drive/Course/Colab Notebooks/training_process_loss1.png", dpi =300)
plt.show()

# %% [markdown]
# ## Saving the model

# %%
# Saving the tokenizer
with open('/content/gdrive/My Drive/Course/Colab Notebooks/BiLSTM_model/Tokenizer.pickle', 'wb') as file:
    pickle.dump(tokenizer, file)

# Saving the BiLSTM-Model.
training_model.save('/content/gdrive/My Drive/Course/Colab Notebooks/BiLSTM_model/BiLSTM_gensim_0839_15epo_100wdataset.h5')
# Out:
# 2020-12-02 22:40:39,838 : INFO : saving Word2VecKeyedVectors object under /content/gdrive/My Drive/Course/Colab Notebooks/BiLSTM_model/Word2Vec-twitter-100-dims01.model, separately None
# 2020-12-02 22:40:39,839 : INFO : not storing attribute vectors_norm
# 2020-12-02 22:40:40,283 : INFO : saved /content/gdrive/My Drive/Course/Colab Notebooks/BiLSTM_model/Word2Vec-twitter-100-dims01.model
# 2020-12-02 22:40:40,285 : INFO : storing 39654x100 projection weights into /content/gdrive/My Drive/Course/Colab Notebooks/BiLSTM_model/Word2Vec-twitter-100-dims-trainable01.model

# %% [markdown]
# ## try predict

# %%
model = training_model
def predict(text):
    
    # Tokenize text
    x_test = pad_sequences(tokenizer.texts_to_sequences([text]), maxlen=60)
    # Predict
    score = model.predict([x_test])[0]
    # Decode sentiment
    #label = -1 if score < 0.5 else 1
    out_score = round(float(score),4)

    return out_score

# %%
predict("I love u so much")
# Out:
# 0.7663

# %%
predict("I'm going under and this time I fear there's no one to save me")
# Out:
# 0.0177
